# %%
from pathlib import Path
import os
import sys

# Set root as parent of current directory
ROOT_DIR = Path.cwd().parent

# Change working directory
os.chdir(ROOT_DIR)

# (Optional) Add to Python path for imports
sys.path.append(str(ROOT_DIR))

print("New working dir:", Path.cwd())
# Out:
# New working dir: c:\Users\Tathagata\Desktop\Code\BruteQuantLabs

# %% [markdown]
# ### Store NSE Symbol List

# %%
import pandas as pd
import requests
import sqlite3

# Step 1: Download all NSE stocks
url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
headers = {"User-Agent": "Mozilla/5.0"}
r = requests.get(url, headers=headers)

print(r.content)

# Step 2: Parse CSV
with open("database/nse_equity_list.csv", "wb") as f:
    f.write(r.content)

df = pd.read_csv("database/nse_equity_list.csv")
df = df[["SYMBOL", "NAME OF COMPANY"]]

print("Total NSE stocks:", len(df))
print(df.head())

# Step 3: Format tickers for Yahoo Finance (add .NS suffix)
df["YF_TICKER"] = df["SYMBOL"].apply(lambda x: x + ".NS")

print("\nSample Yahoo Finance Tickers:")
print(df["YF_TICKER"].head())



conn = sqlite3.connect("database/bql_stock_summary.db")
df.to_sql("stock_list", conn, if_exists="append", index=False)
conn.close()
# Out:
# b"SYMBOL,NAME OF COMPANY, SERIES, DATE OF LISTING, PAID UP VALUE, MARKET LOT, ISIN NUMBER, FACE VALUE\n20MICRONS,20 Microns Limited,EQ,06-OCT-2008,5,1,INE144J01027,5\n21STCENMGM,21st Century Management Services Limited,EQ,03-MAY-1995,10,1,INE253B01015,10\n360ONE,360 ONE WAM LIMITED,EQ,19-SEP-2019,1,1,INE466L01038,1\n3BBLACKBIO,3B Blackbio Dx Limited,EQ,20-APR-2026,10,1,INE994E01018,10\n3IINFOLTD,3i Infotech Limited,EQ,22-OCT-2021,10,1,INE748C01038,10\n3MINDIA,3M India Limited,EQ,13-AUG-2004,10,1,INE470A01017,10\n3PLAND,3P Land Holdings Limited,EQ,19-JUL-1995,2,1,INE105C01023,2\n5PAISA,5Paisa Capital Limited,EQ,16-NOV-2017,10,1,INE618L01018,10\n63MOONS,63 moons technologies limited,EQ,20-JUN-2005,2,1,INE111B01023,2\nA2ZINFRA,A2Z Infra Engineering Limited,BE,23-DEC-2010,10,1,INE619I01012,10\nAAATECH,AAA Technologies Limited,EQ,28-NOV-2022,10,1,INE0D0U01013,10\nAADHARHFC,Aadhar Housing Finance Limited,EQ,15-MAY-2024,10,1,INE883F01010,10\nAAKASH,Aakash Exploration Services Limited,BE,29-SEP-2020,1,1,INE087Z01024,1\nAAREYDRUGS,Aarey Drugs & Pharmaceuticals Limited,BE,06-AUG-2021,10,1,INE198H01019,10\nAARNAV,Aarnav Fashions Limited,EQ,25-FEB-2026,10,1,INE750R01016,10\nAARON,Aaron Industries Limited,EQ,06-NOV-2020,10,1,INE721Z01010,10\nAARTECH,Aartech Solonics Limited,EQ,10-JUL-2
,1\nADANIGREEN,Adani Green Energy Limited,EQ,18-JUN-2018,10,1,INE364U01010,10\nADANIPORTS,Adani Ports and Special Economic Zone Limited,EQ,27-NOV-2007,2,1,INE742F01042,2\nADANIPOWER,Adani Power Limited,EQ,20-AUG-2009,2,1,INE814H01029,2\nADFFOODS,ADF Foods Limited,EQ,15-SEP-2010,2,1,INE982B01027,2\nADL,Archidply Decor Limited,EQ,01-OCT-2020,10,1,INE0CHO01012,10\nADOR,Ador Welding Limited,EQ,10-MAY-1995,10,1,INE045A01017,10\nADROITINFO,Adroit Infotech Limited,EQ,13-AUG-1 ...
# Total NSE stocks: 2360
#        SYMBOL                           NAME OF COMPANY
# 0   20MICRONS                        20 Microns Limited
# 1  21STCENMGM  21st Century Management Services Limited
# 2      360ONE                       360 ONE WAM LIMITED
# 3  3BBLACKBIO                    3B Blackbio Dx Limited
# 4   3IINFOLTD                       3i Infotech Limited
#
# Sample Yahoo Finance Tickers:
# 0     20MICRONS.NS
# 1    21STCENMGM.NS
# 2        360ONE.NS
# 3    3BBLACKBIO.NS
# 4     3IINFOLTD.NS
# Name: YF_TICKER, dtype: str

# %% [markdown]
# ### Nifty 500

# %%
import pandas as pd
import requests
import sqlite3

# Step 1: Download all NSE stocks
url = "https://www.niftyindices.com/IndexConstituent/ind_nifty500list.csv"
headers = {"User-Agent": "Mozilla/5.0"}
r = requests.get(url, headers=headers)

print(r.content)

# Step 2: Parse CSV
with open("database/csv_data/nifty_500.csv", "wb") as f:
    f.write(r.content)

df = pd.read_csv("database/csv_data/nifty_500.csv")
df = df[["Symbol", "Company Name", "Industry"]]

print("Total NSE stocks:", len(df))
print(df.head())

# Step 3: Format tickers for Yahoo Finance (add .NS suffix)
df["YF_TICKER"] = df["Symbol"].apply(lambda x: x + ".NS")

print("\nSample Yahoo Finance Tickers:")
print(df["YF_TICKER"].head())

with open("database/csv_data/nifty_500.csv", "wb") as f:
    f.write(df.to_csv(index=False).encode())
f.close()


# conn = sqlite3.connect("database/bql_stock_summary.db")
# df.to_sql("stock_list", conn, if_exists="append", index=False)
# conn.close()
# Out:
# b"Company Name,Industry,Symbol,Series,ISIN Code\n360 ONE WAM Ltd.,Financial Services,360ONE,EQ,INE466L01038\n3M India Ltd.,Diversified,3MINDIA,EQ,INE470A01017\nABB India Ltd.,Capital Goods,ABB,EQ,INE117A01022\nACC Ltd.,Construction Materials,ACC,EQ,INE012A01025\nACME Solar Holdings Ltd.,Power,ACMESOLAR,EQ,INE622W01025\nAIA Engineering Ltd.,Capital Goods,AIAENG,EQ,INE212H01026\nAPL Apollo Tubes Ltd.,Capital Goods,APLAPOLLO,EQ,INE702C01027\nAU Small Finance Bank Ltd.,Financial Services,AUBANK,EQ,INE949L01017\nAWL Agri Business Ltd.,Fast Moving Consumer Goods,AWL,EQ,INE699H01024\nAadhar Housing Finance Lt
INE437A01024\nApollo Tyres Ltd.,Automobile and Auto Components,APOLLOTYRE,EQ,INE438A01022\nAptus Value Housing Finance India Ltd.,Financial Services,APTUS,EQ,INE852O01025\nAsahi India Glass Ltd.,Automobile and Auto Components,ASAHIINDIA,EQ,INE439A01020\nAshok Leyland Ltd.,Capital Goods,ASHOKLEY,EQ,INE208A01029\nAsian Paints Ltd.,Consumer Durables,ASIANPAINT,EQ,INE021A01026\nAster DM Healthcare Ltd.,Healthcare,ASTERDM,EQ,INE914M01019\nAstral Ltd.,Capital Goods,ASTRAL,EQ,INE006I01046\nAther Energy Ltd.,Automobile and Auto Components,ATHERENERG,EQ,INE0LEZ01016\nAtul Ltd.,Chemicals,ATUL,EQ,INE100A01010\nAurobindo Pharma Ltd.,Healthcare,AUROPHARMA,EQ,INE406A01037\nAuthum Investment & Infrastructure Ltd.,Financial Services,AIIL,EQ,INE206F01022\nAvenue Supermarts Ltd.,Consumer Services,DMART,EQ,INE192R01011\nAxis Bank Ltd.,Financial Services,AXISBANK,EQ,INE238A01034\nBEML Ltd.,Capital Goods,BEML,EQ,INE258A01024\nBLS International Services Ltd.,Consumer Services,BLS,EQ,INE153T01027\nBSE Ltd.,Financial Services,BSE,EQ,INE118H01025\nBajaj Auto Ltd.,Automobile and Auto Components,BAJAJ-A ...
# Total NSE stocks: 504
#       Symbol              Company Name                Industry
# 0     360ONE          360 ONE WAM Ltd.      Financial Services
# 1    3MINDIA             3M India Ltd.             Diversified
# 2        ABB            ABB India Ltd.           Capital Goods
# 3        ACC                  ACC Ltd.  Construction Materials
# 4  ACMESOLAR  ACME Solar Holdings Ltd.                   Power
#
# Sample Yahoo Finance Tickers:
# 0       360ONE.NS
# 1      3MINDIA.NS
# 2          ABB.NS
# 3          ACC.NS
# 4    ACMESOLAR.NS
# Name: YF_TICKER, dtype: str

# %% [markdown]
# ### NIFTY 50

# %%
import pandas as pd
import requests
import sqlite3

# Step 1: Download all NSE stocks
url = "https://www.niftyindices.com/IndexConstituent/ind_nifty50list.csv"
headers = {"User-Agent": "Mozilla/5.0"}
r = requests.get(url, headers=headers)

print(r.content)

# Step 2: Parse CSV
with open("database/csv_data/nifty_50.csv", "wb") as f:
    f.write(r.content)

df = pd.read_csv("database/csv_data/nifty_50.csv")
df = df[["Symbol", "Company Name", "Industry"]]

print("Total NSE stocks:", len(df))
print(df.head())

# Step 3: Format tickers for Yahoo Finance (add .NS suffix)
df["YF_TICKER"] = df["Symbol"].apply(lambda x: x + ".NS")

print("\nSample Yahoo Finance Tickers:")
print(df["YF_TICKER"].head())

with open("database/csv_data/nifty_50.csv", "wb") as f:
    f.write(df.to_csv(index=False).encode())
f.close()


# conn = sqlite3.connect("database/bql_stock_summary.db")
# df.to_sql("stock_list", conn, if_exists="append", index=False)
# conn.close()
# Out:
d.,Power,POWERGRID,EQ,INE752E01010\nReliance Industries Ltd.,Oil Gas & Consumable Fuels,RELIANCE,EQ,INE002A01018\nSBI Life Insurance Company Ltd.,Financial Services,SBILIFE,EQ,INE123W01016\nShriram Finance Ltd.,Financial Services,SHRIRAMFIN,EQ,INE721A01047\nState Bank of India,Financial Services,SBIN,EQ,INE062A01020\nSun Pharmaceutical Industries Ltd.,Healthcare,SUNPHARMA,EQ,INE044A01036\nTata Consultancy Services Ltd.,Information Technology,TCS,EQ,INE467B01029\nTata Consumer Products Ltd.,Fast Moving Consumer Goods,TATACONSUM,EQ,INE192A01025\nTata Motors Passenger Vehicles Ltd.,Automobile and Auto Components,TMPV,EQ,INE155A01022\nTata Steel Ltd.,Metals & Mining,TATASTEEL,EQ,INE081A01020\nTech Mahindra Ltd.,Information Technology,TECHM,EQ,INE669C01036\nTitan Company Ltd.,Consumer Durables,TITAN,EQ,INE280A01028\nTrent Ltd.,Consumer Services,TRENT,EQ,INE849A01020\nUltraTech Cement Ltd.,Construction Materials,ULTRACEMCO,EQ,INE481G01011\nWipro Ltd.,Information Technology,WIPRO,EQ,INE075A01022\n"
# Total NSE stocks: 50
#        Symbol                                Company Name            Industry
# 0    ADANIENT                      Adani Enterprises Ltd.     Metals & Mining
# 1  ADANIPORTS  Adani Ports and Special Economic Zone Ltd.            Services
# 2  APOLLOHOSP            Apollo Hospitals Enterprise Ltd.          Healthcare
# 3  ASIANPAINT                           Asian Paints Ltd.   Consumer Durables
# 4    AXISBANK                              Axis Bank Ltd.  Financial Services
#
# Sample Yahoo Finance Tickers:
# 0      ADANIENT.NS
# 1    ADANIPORTS.NS
# 2    APOLLOHOSP.NS
# 3    ASIANPAINT.NS
# 4      AXISBANK.NS
# Name: YF_TICKER, dtype: str

# %%
import yfinance as yf
ret = yf.download("RELIANCE.NS", start="2020-01-01", end="2026-01-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ret
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2020-01-01   675.324219   683.152914   673.490123   679.081997    14004468
# 2020-01-02   686.821228   689.348791   676.397899   676.397899    17710316
# 2020-01-03   687.648804   689.661895   681.318729   685.792252    20984698
# 2020-01-06   671.700684   683.510767   670.134933   679.976719    24519177
# 2020-01-07   682.034546   686.463335   677.068889   679.529321    16683622
# ...                 ...          ...          ...          ...         ...
# 2026-01-23  1386.099976  1407.000000  1381.000000  1401.800049     9837802
# 2026-01-27  1380.500000  1391.599976  1368.000000  1380.000000    26302396
# 2026-01-28  1396.699951  1409.900024  1384.900024  1385.000000    11121657
# 2026-01-29  1391.000000  1402.900024  1384.000000  1402.900024    20846683
# 2026-01-30  1395.400024  1398.000000  1378.500000  1382.599976    11239835
#
# [1508 rows x 5 columns]

# %%
import yfinance as yf

tickers = ["TCS.NS", "RELIANCE.NS", "ITC.NS"]

df = yf.download(
    tickers,
    period="max",
    interval="1d",
    group_by="ticker",
    auto_adjust=True,
    threads=False  # safer to avoid rate limits
)

print(df)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker           TCS.NS                                                    \
# Price              Open         High          Low        Close     Volume
# Date
# 1996-01-01          NaN          NaN          NaN          NaN        NaN
# 1996-01-02          NaN          NaN          NaN          NaN        NaN
# 1996-01-03          NaN          NaN          NaN          NaN        NaN
# 1996-01-04          NaN          NaN          NaN          NaN        NaN
# 1996-01-05          NaN          NaN          NaN          NaN        NaN
# ...                 ...          ...          ...          ...        ...
# 2026-04-24  2488.000000  2505.000000  2388.800049  2396.899902  5107719.0
# 2026-04-27  2396.899902  2459.000000  2396.899902  2447.600098  5853425.0
# 2026-04-28  2444.000000  2487.000000  2427.399902  2444.699951  4508363.0
# 2026-04-29  2451.000000  2487.899902  2447.600098  2474.699951  2835961.0
# 2026-04-30          NaN          NaN          NaN          NaN  3970110.0
#
# Ticker      RELIANCE.NS                                                      \
# Price              Open         High          Low        Close       Volume
# Date
# 1996-01-01     4.600219     4.624903     4.569925     4.617049  104121369.0
# 1996-01-02     4.605828     4.628267     4.547483     4.581143  168743308.0
# 1996-01-03     4.656318     4.868378     4.605829     4.615927  209323879.0
# 1996-01-04     4.572169     4.586754     4.511580     4.573290  216900264.0
# 1996-01-05     4.555339     4.555339     4.502604     4.541874  166708467.0
# ...                 ...          ...          ...          ...          ...
# 2026-04-24  1340.000000  1345.900024  1325.000000  1327.800049   11744802.0
# 2026-04-27  1313.000000  1371.599976  1311.000000  1365.800049   24673098.0
# 2026-04-28  1358.000000  1395.199951  1357.000000  1388.900024   41027699.0
# 2026-04-29  1392.000000  1433.800049  1391.300049  1425.400024   30542143.0
# 2026-04-30          NaN          NaN          NaN          NaN   30956783.0
#
# Ticker          ITC.NS
# Price             Open        High         Low       Close      Volume
# Date
# 1996-01-01    2.653953    2.677863    2.645984    2.669893   1023454.0
# 1996-01-02    2.614104    2.661923    2.529092    2.568941   7757692.0
# 1996-01-03    2.454707    2.512621    2.439299    2.486587  15744376.0
# 1996-01-04    2.486587    2.549814    2.460020    2.533342  12874964.0
# 1996-01-05    2.533343    2.523779    2.481274    2.487649   5201392.0
# ...                ...         ...         ...         ...         ...
# 2026-04-24  306.649994  306.649994  301.100006  301.600006  17011704.0
# 2026-04-27  303.649994  305.649994  302.850006  303.850006  14382348.0
# 2026-04-28  304.399994  305.799988  302.549988  304.450012  12907339.0
# 2026-04-29  305.100006  317.500000  305.100006  316.250000  31199038.0
# 2026-04-30         NaN         NaN         NaN         NaN  11478573.0
#
# [7612 rows x 15 columns]

# %% [markdown]
# # BACKGROUND JOBS - WARNING

# %%
import sqlite3

conn = sqlite3.connect("database/bql_stock_prices.db")
cursor = conn.cursor()

cursor.execute("DROP TABLE IF EXISTS stock_list")

conn.commit()
conn.close()
